# %% [markdown]
# # Logistic Regression

# %% [markdown]
# ## import library

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as colors

# %% [markdown]
# ## load training data

# %%
fname_data = 'assignment_08_data.csv'

data = np.genfromtxt(fname_data, delimiter=',')
num_data = data.shape[0]

point_x = np.zeros(num_data)
point_y = np.zeros(num_data)
label   = np.zeros(num_data)

for i in range(num_data):

    point_x[i]  = data[i,0]
    point_y[i]  = data[i,1]
    label[i]    = data[i,2]

# %%
ones = np.ones(shape=(len(point_x),))
data_matrix = np.c_[ones.T, point_x.T, point_y.T] # (600,3)

# %% [markdown]
# ## define linear regression function with inputs $\theta = (\theta_0, \theta_1, \theta_2)$ and ${\rm point} = (1, x, y)$

# %%
def linear_regression(theta, data_matrix):

    func = np.dot(data_matrix, theta.T)
    
    return func

# %% [markdown]
# ## define sigmoid function with input $x$

# %%
def sigmoid(z):
    
    # sigmoid function 
    sig_z = 1 / (1 + np.exp(-z))
    
    return sig_z

# %% [markdown]
# ## define loss function for the logistic regression

# %%
# Logistic regression function
def logistic_regression(theta, data_matrix):
    
    h = sigmoid(linear_regression(theta, data_matrix))
    
    return h

# %%
def compute_loss(theta, data_matrix):

    h = logistic_regression(theta, data_matrix)
    loss = (1 / len(h)) * np.sum((-label*np.log(h) - (1-label)*np.log(1-h)))
    
    return loss

# %% [markdown]
# ## define gradient vector for the model parameters $\theta = (\theta_0, \theta_1, \theta_2)$

# %%
def compute_gradient(theta, data_matrix):
    
    gradient= (1 / 600) * np.dot(data_matrix.T, (logistic_regression(theta, data_matrix) - label))
    
    return gradient

# %% [markdown]
# ## gradient descent for the model parameters $\theta = (\theta_0, \theta_1, \theta_2)$

# %%
num_iteration   = 5000  # USE THIS VALUE for the number of gradient descent iterations 
learning_rate   = 0.001 # USE THIS VALUE for the learning rate
theta           = np.array((0, 0, 0))   # USE THIS VALUE for the initial condition of the model parameters

# %% [markdown]
# ## iterations for the gradient descent

# %%
theta_iteration = np.zeros((num_iteration, theta.size))
loss_iteration  = np.zeros(num_iteration)

# %%
for i in range(num_iteration):
    
    theta = theta - learning_rate * compute_gradient(theta, data_matrix)
    theta_iteration[i] = theta
    
    loss = compute_loss(theta, data_matrix)
    loss_iteration[i] = loss
    
    print("iteration = %4d, loss = %5.5f" % (i, loss))
# Out:
# iteration =    0, loss = 0.66813
# iteration =    1, loss = 0.64476
# iteration =    2, loss = 0.62295
# iteration =    3, loss = 0.60256
# iteration =    4, loss = 0.58350
# iteration =    5, loss = 0.56567
# iteration =    6, loss = 0.54897
# iteration =    7, loss = 0.53332
# iteration =    8, loss = 0.51864
# iteration =    9, loss = 0.50485
# iteration =   10, loss = 0.49188
# iteration =   11, loss = 0.47967
# iteration =   12, loss = 0.46817
# iteration =   13, loss = 0.45731
# iteration =   14, loss = 0.44706
# iteration =   15, loss = 0.43736
# iteration =   16, loss = 0.42817
# iteration =   17, loss = 0.41947
# iteration =   18, loss = 0.41121
# iteration =   19, loss = 0.40336
# iteration =   20, loss = 0.39590
# iteration =   21, loss = 0.38879
# iteration =   22, loss = 0.38202
# iteration =   23, loss = 0.37557
# iteration =   24, loss = 0.36940
# iteration =   25, loss = 0.36351
# iteration =   26, loss = 0.35787
# iteration =   27, loss = 0.35248
# ...

# %% [markdown]
# ## plot the results

# %%
def plot_loss_curve(loss_iteration):

    plt.figure(figsize=(8,6))   
    plt.title('loss')
    
    x = np.arange(0, num_iteration)
    y = loss_iteration
    
    plt.plot(x, y, color='red')

    plt.xlabel('iteration')
    plt.ylabel('loss')

    plt.tight_layout()
    plt.show()

# %%
def plot_data(data):
    
    class0 = data[data[:,2] == 0][:,0:2]
    class1 = data[data[:,2] == 1][:,0:2]

    plt.figure(figsize=(8,8))

    plt.title('training data')
    
    plt.plot(class0[:,0], class0[:,1], '.', color = 'blue', label = 'class0')
    plt.plot(class1[:,0], class1[:,1], '.', color = 'red', label = 'class1')
    
    plt.axis('equal')
    plt.legend()
    plt.tight_layout()
    plt.show()

# %%
def plot_model_parameter(theta_iteration):

    plt.figure(figsize=(8,6))
    plt.title('model parameter')
    x = np.arange(0, num_iteration)
    
    theta0 = [theta for theta in theta_iteration.T[0]]
    theta1 = [theta for theta in theta_iteration.T[1]]
    theta2 = [theta for theta in theta_iteration.T[2]]
    
    plt.plot(x, theta0, color = 'red', label = 'theta0')
    plt.plot(x, theta1, color = 'green', label = 'theta1')
    plt.plot(x, theta2, color = 'blue', label = 'theta2')
    
    plt.xlabel('iteration')
    plt.legend()

    plt.tight_layout()
    plt.show()

# %%
xmax = max(point_x) # 27.928425103146765
xmin = min(point_x) # -14.862640234839995
ymax = max(point_y) # 29.70084125935566
ymin = min(point_y) # -14.529676670279413

# %%
def plot_classifier(data):
    
    plt.figure(figsize=(8,8))
    plt.title('classifier with the given data points superimposed')

    # meshgrid
    x_value = np.arange(-15, 30, 0.01)
    y_value = np.arange(-15, 30, 0.01)
    xs, ys = np.meshgrid(x_value, y_value)
    z = theta[0] + theta[1] * xs + theta[2] * ys
    plt.pcolormesh(xs, ys, z, cmap='RdBu_r')
    plt.colorbar()

    # data plot
    class0 = data[data[:,2] == 0][:,0:2]
    class1 = data[data[:,2] == 1][:,0:2]
    plt.plot(class0[:,0], class0[:,1], '.', color = 'blue', label = 'class0')
    plt.plot(class1[:,0], class1[:,1], '.', color = 'red', label = 'class1')

    # linear regression function
    f = (-theta[0]-theta[1]*x_value)/theta[2]
    plt.plot(x_value, f, color = 'k')

    plt.axis('equal')
    plt.legend()

    plt.show()

# %% [markdown]
# # * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *

# %% [markdown]
# # * results

# %% [markdown]
# # * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *

# %% [markdown]
# ### # 01. plot the input data point in blue for class 0 and in red for class 1

# %%
plot_data(data)

# %% [markdown]
# ### # 02. plot the values of the model parameters $\theta_0$ in red curve, $\theta_1$ in green curve, and $\theta_2$ in blue curve over the gradient descent iterations

# %%
plot_model_parameter(theta_iteration)

# %% [markdown]
# ### # 03. plot the loss values $\mathcal{L}(\theta)$ in red curve over the gradient descent iterations

# %%
plot_loss_curve(loss_iteration)

# %% [markdown]
# ### # 04. plot the classifier with the given data points superimposed

# %%
plot_classifier(data)
# Out:
# <ipython-input-16-54b61dff1fbd>:11: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   plt.pcolormesh(xs, ys, z, cmap='RdBu_r')
